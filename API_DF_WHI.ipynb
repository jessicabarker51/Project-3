# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
api_key = 'WJRjJA93Ow+qiCIi55CpWp4mpSZFuBkfPXpet7Zz9DSDVWSvyTpzxrC9JvPgtf/G'
url = 'https://api.collegefootballdata.com/recruiting/players?year=2022&classification=HighSchool'  

headers = {
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json'
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()  # Extract the response data in JSON format
    # Process the data as needed
    pprint(data)
else:
    print(f'Request failed with status code {response.status_code}')
# Out:
# [{'athleteId': '4685415',
#   'city': 'Suwanee',
#   'committedTo': 'Jackson State',
#   'country': 'USA',
#   'height': 73,
#   'hometownInfo': {'fipsCode': '13135',
#                    'latitude': '34.0514898',
#                    'longitude': '-84.0712997'},
#   'id': '90104',
#   'name': 'Travis Hunter',
#   'position': 'CB',
#   'ranking': 1,
#   'rating': 0.9999,
#   'recruitType': 'HighSchool',
#   'school': 'Collins Hill',
#   'stars': 5,
#   'stateProvince': 'GA',
#   'weight': 165,
#   'year': 2022},
#  {'athleteId': '4685503',
#   'city': 'Powell',
#   'committedTo': 'Texas A&M',
#   'country': 'USA',
#   'height': 76,
#   'hometownInfo': {'fipsCode': '47093',
#                    'latitude': '36.0317472',
#                    'longitude': '-84.0279677'},
#   'id': '90105',
#   'name': 'Walter Nolen',
#   'position': 'DL',
#   'ranking': 2,
#   'rating': 0.9998,
#   'recruitType': 'HighSchool',
#   'school': 'Powell',
#   'stars': 5,
#   'stateProvince': 'TN',
# ...
